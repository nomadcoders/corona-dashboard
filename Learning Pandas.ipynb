# %%
import pandas as pd

daily_df = pd.read_csv("data/daily_report.csv")

daily_df
# Out:
#       FIPS Admin2 Province_State      Country_Region          Last_Update  \
# 0      NaN    NaN            NaN         Afghanistan  2020-08-13 04:29:15
# 1      NaN    NaN            NaN             Albania  2020-08-13 04:29:15
# 2      NaN    NaN            NaN             Algeria  2020-08-13 04:29:15
# 3      NaN    NaN            NaN             Andorra  2020-08-13 04:29:15
# 4      NaN    NaN            NaN              Angola  2020-08-13 04:29:15
# ...    ...    ...            ...                 ...                  ...
# 3938   NaN    NaN            NaN  West Bank and Gaza  2020-08-13 04:29:15
# 3939   NaN    NaN            NaN      Western Sahara  2020-08-13 04:29:15
# 3940   NaN    NaN            NaN               Yemen  2020-08-13 04:29:15
# 3941   NaN    NaN            NaN              Zambia  2020-08-13 04:29:15
# 3942   NaN    NaN            NaN            Zimbabwe  2020-08-13 04:29:15
#
#             Lat      Long_  Confirmed  Deaths  Recovered  Active  \
# ...
